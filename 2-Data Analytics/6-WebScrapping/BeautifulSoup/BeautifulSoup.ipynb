# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página de libros más vendidos de Book Depository, y para lograr esto, también tendrá que hacer uso de un poco de pandas principalmente..

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 3.5 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.11.1 soupsieve-2.3.2.post1

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parswer, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 6.3 MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.9.1

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (2.22.0)

# %% [markdown]
# Ahora asi manos a la obra..

# %%
# !pip install splinter
# Out:
# Collecting splinter
#   Downloading splinter-0.18.1-py3-none-any.whl (37 kB)
# Installing collected packages: splinter
# Successfully installed splinter-0.18.1

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from splinter import Browser
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.bookdepository.com/bestsellers"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %%
# html

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
# print(html)

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "lxml")

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los libros más vendidos)
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." name="description"/>
# <meta content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <link href="https://www.bookdepository.com/bestsellers" rel="canonical"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/bestsellers" hreflang="es" rel="alternate"/>
# <link href="/bestsellers?page=2" rel="next"/>
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# </head>
# <body class="seasonal-theme-xmas">
# <div aria-describedby="bd_cookie_consent_popup_text" aria-labelledby="bd_cookie_consent_popup_hd1" class="cookie-consent" role="alertdialog">
# <div class="cookie-consent-content">
# <h2>We use cookies to improve this site</h2>
# <p>Cookies are used to provide, analyse and improve our services; provide chat tools; and show<br/>you relevant content on advertising. To learn more about our use of cookies, read our <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies Help section</a></p><h2>Are you happy to accept cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <button class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Accept cookies</button>
# <button class="btn btn-sm btn-secondary btn-manage" href="#" rel="nofollow">
#                 Manage cookies</button>
# </div>
# </div>
# <div class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Cookie Preferences</h2>
# <p>We use cookies and similar tools that are necessary to enable you to make purchases, including those used by approved third parties (collectively, "cookies") for the purposes described below.
#      <br/>You can learn more about how we (plus approved third parties) use cookies and how to change your settings by visiting the <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>. The choices you make here will apply to your interaction with this service on this device.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Essential</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>We use cookies to provide our services, </span>
# <div>
# <div class="additionalInfo wrapping-space"> for example, to keep track of items stored in your shopping basket, prevent fraudulent activity, improve the security of our services, keep track of your specific preferences (such as currency or language preferences), and display features, products and services that might be of interest to you. Because we use cookies to provide you our services, they cannot be disabled when used for these purposes.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Performance and Analytics</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="performanceCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to understand how customers use our services</span>
# <div>
# <div class="additionalInfo wrapping-space"> (for example, by measuring site visits) so we can make improvements. We use cookies to conduct research and diagnostics to improve our content, products and services, and to measure and analyse the performance of our services.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Advertising</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to complement your shopping experience, as described in our <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookie Notice</a></span>
# <div>
# <div class="additionalInfo wrapping-space"> and serve you certain types of ads relevant to your interests on Book Depository. This includes using third party cookies for the purpose of displaying and measuring ads (see the <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Interest-Based Ads</a> notice for how we use cookies in serving interest-based ads), measuring the effectiveness of ads, and as necessary for the third party to perform services on behalf of Book Depository.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <a class="btn btn-sm btn-secondary btn-cancel" href="#" rel="nofollow">
#                 Cancel</a>
# <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Save settings</a>
# </div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/"><i class="icon-home"></i><span class="show-non-desktop">Home</span></a></li>
# <li class="mob-nav-account"><a href="/contactus"><i class="icon-em"></i>Contact us</a></li>
# <li class="mob-nav-account"><a href="/help" rel="nofollow"><i class="icon-info"></i>Help</a></li>
# </ul>
# <div class="middle-nav">
# <div class="two-part-banner cyber-week">
# <a class="free-delivery-block" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#                                 FREE<br/>DELIVERY</a>
# <a class="promotion-block" href="/cyber-monday" rel="nofollow" title=""></a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/track" rel="nofollow"><i class="icon-order-status"></i>Order Status</a>
# </li>
# <li class="mob-nav-account"><a href="/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Wishlist</a>
# </li>
# <li class="mob-nav-account"><a href="/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Sign in/Join</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Search for books by keyword / title / author / ISBN" class="text-input" name="searchTerm" placeholder="Search for books by keyword / title / author / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Search</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/search/advanced" rel="nofollow">Advanced Search</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Free delivery worldwide" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="two-part-ribbon cyber-week">
# <a class="free-delivery-ribbon-block" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#                             FREE<br/>DELIVERY</a>
# <a class="promotion-ribbon-block" href="/cyber-monday" rel="nofollow" title=""></a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Shop by category</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categories</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Children's Age Ranges</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 All Categories</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Browse All</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Children's books by age range</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/bestsellers">Bestsellers</a></li>
# <li class="mob-nav-shop"><a href="/top-new-releases">New Releases</a>
# </li>
# <li class="mob-nav-shop">
# <a href="/Christmas-FAQs">
#                             Christmas FAQs</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         English</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Languages</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             English</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Spanish (Español)</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="English">
# <select id="selectLanguage" name="selectLanguage">
# <option selected="selected" value="en_US">
#                     English</option>
# <option value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/bestsellers" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="content-wrap">
# <div class="sidebar">
# <div class="sidebar-section search-filter">
# <h2>Filter your search</h2>
# <div class="sidebar-section-content search-filter-sidebar">
# <form action="/bestsellers" class="filter-menu" method="get">
# <div class="form-group">
# <label for="searchTerm">Keyword</label>
# <input class="form-control" name="searchTerm" spellcheck="false" type="text" value=""/>
# </div>
# <input name="searchSortBy" type="hidden" value=""/>
# <input name="category" type="hidden" value=""/>
# <div class="form-group">
# <label for="filter_price">Price range</label>
# <select class="form-control" id="filterPrice" name="price">
# <option label="All" value="">
# 							All</option>
# <option label="Under €15" value="low">
# 							Under €15</option>
# <option label="€15 to €30" value="med">
# 							€15 to €30</option>
# <option label="€30 +" value="high">
# 							€30 +</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_availability">Availability</label>
# <select class="form-control" id="filterAvailability" name="availability">
# <option label="All" value="">
# 							All</option>
# <option label="In stock (97881)" value="1">
# 							In stock (97881)</option>
# <option label="Pre-order (2027)" value="2">
# 							Pre-order (2027)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_search_lang">Language</label>
# <select class="form-control" id="filterLang" name="searchLang">
# <option label="All" value="">
# 							All</option>
# <option label="English (93824)" value="123">
# 							English (93824)</option>
# <option label="French (580)" value="137">
# 							French (580)</option>
# <option label="Spanish (2290)" value="404">
# 							Spanish (2290)</option>
# <option label="German (1582)" value="150">
# 							German (1582)</option>
# <option label="Latin (31)" value="246">
# 							Latin (31)</option>
# <option label="Italian (238)" value="202">
# 							Italian (238)</option>
# <option label="Chinese (274)" value="79">
# 							Chinese (274)</option>
# <option label="Russian (40)" value="365">
# 							Russian (40)</option>
# <option label="Japanese (81)" value="205">
# 							Japanese (81)</option>
# <option label="Dutch; Flemish (17)" value="116">
# 							Dutch; Flemish (17)</option>
# <option label="Afrikaans (4)" value="9">
# 							Afrikaans (4)</option>
# <option label="Arabic (49)" value="21">
# 							Arabic (49)</option>
# <option label="Armenian (1)" value="24">
# 							Armenian (1)</option>
# <option label="Basque (5)" value="44">
# 							Basque (5)</option>
# <option label="Belarusian (3)" value="48">
# 							Belarusian (3)</option>
# <option label="Bulgarian (1)" value="65">
# 							Bulgarian (1)</option>
# <option label="Catalan (12)" value="71">
# 							Catalan (12)</option>
# <option label="Coptic (1)" value="90">
# 							Coptic (1)</option>
# <option label="Croatian (1)" value="181">
# 							Croatian (1)</option>
# <option label="Czech (7)" value="101">
# 							Czech (7)</option>
# <option label="Danish (2)" value="103">
# 							Danish (2)</option>
# <option label="English, Old (ca. 450-1100) (2)" value="18">
# 							English, Old (ca. 450-1100) (2)</option>
# <option label="Esperanto (2)" value="125">
# 							Esperanto (2)</option>
# <option label="Estonian (1)" value="126">
# 							Estonian (1)</option>
# <option label="Finnish (55)" value="134">
# 							Finnish (55)</option>
# <option label="Galician (2)" value="155">
# 							Galician (2)</option>
# <option label="Greek, Ancient (to 1453) (9)" value="163">
# 							Greek, Ancient (to 1453) (9)</option>
# <option label="Greek, Modern (1453-) (35)" value="164">
# 							Greek, Modern (1453-) (35)</option>
# <option label="Gujarati (1)" value="167">
# 							Gujarati (1)</option>
# <option label="Hebrew (13)" value="173">
# 							Hebrew (13)</option>
# <option label="Hindi (3)" value="177">
# 							Hindi (3)</option>
# <option label="Hungarian (5)" value="183">
# 							Hungarian (5)</option>
# <option label="Icelandic (2)" value="187">
# 							Icelandic (2)</option>
# <option label="Iranian languages (1)" value="200">
# 							Iranian languages (1)</option>
# <option label="Irish (23)" value="154">
# 							Irish (23)</option>
# <option label="Korean (142)" value="231">
# 							Korean (142)</option>
# <option label="Maori (2)" value="270">
# 							Maori (2)</option>
# <option label="Marathi (1)" value="272">
# 							Marathi (1)</option>
# <option label="Multiple languages (15)" value="292">
# 							Multiple languages (15)</option>
# <option label="Nahuatl languages (1)" value="299">
# 							Nahuatl languages (1)</option>
# <option label="Nepali (1)" value="308">
# 							Nepali (1)</option>
# <option label="No linguistic content (7)" value="486">
# 							No linguistic content (7)</option>
# <option label="Norwegian (6)" value="317">
# 							Norwegian (6)</option>
# <option label="Old Norse (1)" value="316">
# 							Old Norse (1)</option>
# <option label="Persian (2)" value="343">
# 							Persian (2)</option>
# <option label="Polish (455)" value="347">
# 							Polish (455)</option>
# <option label="Portuguese (120)" value="349">
# 							Portuguese (120)</option>
# <option label="Pushto; Pashto (1)" value="352">
# 							Pushto; Pashto (1)</option>
# <option label="Romanian (57)" value="362">
# 							Romanian (57)</option>
# <option label="Sanskrit (5)" value="372">
# 							Sanskrit (5)</option>
# <option label="Scots (5)" value="377">
# 							Scots (5)</option>
# <option label="Scottish Gaelic (7)" value="153">
# 							Scottish Gaelic (7)</option>
# <option label="Slovak (4)" value="388">
# 							Slovak (4)</option>
# <option label="Swedish (116)" value="415">
# 							Swedish (116)</option>
# <option label="Tagalog (3)" value="427">
# 							Tagalog (3)</option>
# <option label="Tamil (3)" value="420">
# 							Tamil (3)</option>
# <option label="Thai (2)" value="428">
# 							Thai (2)</option>
# <option label="Turkish (9)" value="446">
# 							Turkish (9)</option>
# <option label="Ukrainian (13)" value="454">
# 							Ukrainian (13)</option>
# <option label="Undetermined (4)" value="456">
# 							Undetermined (4)</option>
# <option label="Welsh (14)" value="468">
# 							Welsh (14)</option>
# <option label="Yiddish (6)" value="476">
# 							Yiddish (6)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="">Format</label>
# <select class="form-control" id="filterFormat" name="format">
# <option label="All" value="">
# 							All</option>
# <option label="Paperback" value="1">
# 							Paperback</option>
# <option label="Hardback" value="2">
# 							Hardback</option>
# <option label="Audio" value="3">
# 							Audio</option>
# <option label="Baby Books" value="4">
# 							Baby Books</option>
# <option label="Digital" value="5">
# 							Digital</option>
# <option label="Maps" value="6">
# 							Maps</option>
# <option label="Stationery" value="7">
# 							Stationery</option>
# <option label="Toys" value="8">
# 							Toys</option>
# </select>
# </div>
# <div class="form-group padded-btn-wrap">
# <button class="btn btn-primary" type="submit">
# 					Refine results</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="main-content bestseller-page">
# <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filter your search">Filter your search</a>
# <h1>Bestsellers – our most popular items, updated daily.</h1>
# <div class="head-block">
# <div class="search-info left-content" id="search-info">
#                 Showing 1 to 30 of <span class="search-count">1,000</span> results</div>
# <div class="right-content">
# <ul class="pagination pagination-sm responsive-pagination">
# <li class="active"><a>1</a></li>
# <li><a href="/bestsellers?page=2">2</a></li>
# <li><a href="/bestsellers?page=3">3</a></li>
# <li><a href="/bestsellers?page=4">4</a></li>
# <li><a href="/bestsellers?page=5">5</a></li>
# <li class="next" id="next-top"><a href="/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# <div class="content-block">
# <div class="block-wrap search no-heading">
# <div class="block">
# <div class="tab-wrap module type-book grid tab--2 tab-active">
# <div class="tab">
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
# <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
# </a>
# </div>
# <meta content="9781471156267" itemprop="isbn"/>
# <meta content="It Ends With Us: The most heartbreaking novel you'll ever read" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                     It Ends With Us: The most heartbreaking novel you'll ever read<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Aug 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">12,84 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471156267" data-price="12.84" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Verity-Colleen-Hoover/9781408726600" itemprop="url">
# <img alt="Verity" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
# </a>
# </div>
# <meta content="9781408726600" itemprop="isbn"/>
# <meta content="Verity" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Verity-Colleen-Hoover/9781408726600">
#                     Verity<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Verity" href="/Verity-Colleen-Hoover/9781408726600">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">20 Jan 2022</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">11,94 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408726600" data-price="11.94" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581" itemprop="url">
# <img alt="Before the Coffee Gets Cold" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5290/9781529029581.jpg"/>
# </a>
# </div>
# <meta content="9781529029581" itemprop="isbn"/>
# <meta content="Before the Coffee Gets Cold" itemprop="name"/>
# <meta content="Toshikazu Kawaguchi" itemprop="contributor"/>
# <meta content="Geoffrey Trousselot" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#                     Before the Coffee Gets Cold<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Toshikazu-Kawaguchi" itemprop="author">Toshikazu Kawaguchi</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Before the Coffee Gets Cold" href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">19 Sep 2019</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">14,15 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529029581" data-price="14.15" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781529029581" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
# <img alt="Atomic Habits" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
# </a>
# </div>
# <meta content="9781847941831" itemprop="isbn"/>
# <meta content="Atomic Habits" itemprop="name"/>
# <meta content="James Clear" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Atomic-Habits-James-Clear/9781847941831">
#                     Atomic Habits<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/James-Clear" itemprop="author">James Clear</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Atomic Habits" href="/Atomic-Habits-James-Clear/9781847941831">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Nov 2018</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">20,68 €</span>
# <span class="rrp-label">
# <a href="/help/topic/HelpId/RRP#helpContent">
#                                         RRP</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">21,50 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                         30-day low price</a>:
#                                     <span class="price-save">
#                                         20,68 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781847941831" data-price="20.68" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Tools-Phil-Stutz/9780812983043" itemprop="url">
# <img alt="The Tools" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/8129/9780812983043.jpg"/>
# </a>
# </div>
# <meta content="9780812983043" itemprop="isbn"/>
# <meta content="The Tools" itemprop="name"/>
# <meta content="Phil Stutz" itemprop="contributor"/>
# <meta content="Barry Michels" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Tools-Phil-Stutz/9780812983043">
#                     The Tools<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Phil-Stutz" itemprop="author">Phil Stutz</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Tools" href="/Tools-Phil-Stutz/9780812983043">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">09 Oct 2014</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">20,11 €</span>
# <span class="rrp-label">
# <a href="/help/topic/HelpId/RRP#helpContent">
#                                         RRP</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">20,50 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                         30-day low price</a>:
#                                     <span class="price-save">
#                                         18,96 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780812983043" data-price="20.11" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780812983043" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697" itemprop="url">
# <img alt="Seven Husbands of Evelyn Hugo" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515697.jpg"/>
# </a>
# </div>
# <meta content="9781398515697" itemprop="isbn"/>
# <meta content="Seven Husbands of Evelyn Hugo" itemprop="name"/>
# <meta content="Taylor Jenkins Reid" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#                     Seven Husbands of Evelyn Hugo<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Taylor-Jenkins-Reid" itemprop="author">Taylor Jenkins Reid</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Seven Husbands of Evelyn Hugo" href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">14 Oct 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">12,89 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515697" data-price="12.89" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781398515697" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555" itemprop="url">
# <img alt="Roald Dahl's Marvellous Joke Book" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1413/9780141340555.jpg"/>
# </a>
# </div>
# <meta content="9780141340555" itemprop="isbn"/>
# <meta content="Roald Dahl's Marvellous Joke Book" itemprop="name"/>
# <meta content="Roald Dahl" itemprop="contributor"/>
# <meta content="Quentin Blake" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555">
#                     Roald Dahl's Marvellous Joke Book<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Roald-Dahl" itemprop="author">Roald Dahl</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Roald Dahl's Marvellous Joke Book" href="/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">06 Sep 2012</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">20,78 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141340555" data-price="20.78" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780141340555" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Letters-from-M-M-Paris-Paul-McNeil/9780500025277" itemprop="url">
# <img alt="Letters from M/M (Paris)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5000/9780500025277.jpg"/>
# <div class="savings-splat">
#                         13%<br/>off</div>
# </a>
# </div>
# <meta content="9780500025277" itemprop="isbn"/>
# <meta content="Letters from M/M (Paris)" itemprop="name"/>
# <meta content="Paul McNeil" itemprop="contributor"/>
# <meta content="Bjoerk" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Letters-from-M-M-Paris-Paul-McNeil/9780500025277">
#                     Letters from M/M (Paris)<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Paul-McNeil" itemprop="author">Paul McNeil</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">24 Jan 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">53,78 €</span>
# <span class="rrp-label">
# <a href="/help/topic/HelpId/RRP#helpContent">
#                                         RRP</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">62,50 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                         30-day low price</a>:
#                                     <span class="price-save">
#                                         53,78 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780500025277" data-price="53.78" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780500025277" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# ...
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Ugly Love" href="/Ugly-Love-Colleen-Hoover/9781471136726">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Jan 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">13,15 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471136726" data-price="13.15" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471136726" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532" itemprop="url">
# <img alt="They Know Not What They Do" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7860/9781786073532.jpg"/>
# </a>
# </div>
# <meta content="9781786073532" itemprop="isbn"/>
# <meta content="They Know Not What They Do" itemprop="name"/>
# <meta content="Jussi Valtonen" itemprop="contributor"/>
# <meta content="Kristian London" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532">
#                     They Know Not What They Do<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Jussi-Valtonen" itemprop="author">Jussi Valtonen</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for They Know Not What They Do" href="/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">13 Nov 2018</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">14,41 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781786073532" data-price="14.41" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781786073532" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script></div>
# <div class="foot-block">
# <div class="right-content">
# <ul class="pagination pagination-sm">
# <li class="active"><a>1</a></li>
# <li><a href="/bestsellers?page=2">2</a></li>
# <li><a href="/bestsellers?page=3">3</a></li>
# <li><a href="/bestsellers?page=4">4</a></li>
# <li><a href="/bestsellers?page=5">5</a></li>
# <li class="next" id="next-bottom"><a href="/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# </div></div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/newsletter/add">
# <div class="form-group">
# <input aria-label="Email address for newsletter subscription" class="form-control" name="newsletterEmailAddress" placeholder="Email address" spellcheck="false" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                 Sign up now</button>
# </div>
# </form>
# </div>
# </div>
# </div></div>
# <div class="footer-social-wrap">
# <h4>
#             Follow us</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Explore</h4>
# <ul>
# <li><a href="/about-us" rel="nofollow">
#                             About us</a></li>
# <li><a href="/sitemap">
#                             Sitemap</a></li>
# <li><a href="/bookmarks">
#                             Bookmarks</a></li>
# <li><a class="footer-sign-in-link" href="/account/login/to/account">
#                                     Sign in/Join</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>How can we help?</h4>
# <ul>
# <li>
# <a href="/help" rel="nofollow">
#                                 Help</a>
# </li>
# <li>
# <a href="/contactus">
#                                 Contact us</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 Where's my stuff?</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 Where do you deliver?</a>
# </li>
# <li>
# <a href="/cancelorder" rel="nofollow">
#                                 Cancel my order</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/30#helpContent" rel="nofollow">
#                                 Return my order</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Join us</h4>
# <ul>
# <li><a href="/affiliate">
#                             Affiliates</a></li>
# <li><a href="/jobs">
#                             Jobs</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Important stuff</h4>
# <ul>
# <li>
# <a href="/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Complaints</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Privacy policy</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Terms &amp; Conditions</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/account/login/to/account" rel="nofollow">
#                                     Sign in/Join</a></li>
# <li><a href="/track">
#                             Order Status</a></li>
# <li><a href="/contactus">
#                             Contact us</a></li>
# <li><a href="/help">
#                             Help</a></li>
# <li><a href="/about-us" rel="nofollow">
#                             About us</a></li>
# <li><a href="/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Terms &amp; Conditions</a></li>
# <li><a href="/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Privacy policy</a></li>
# <li><a href="/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>We accept these payment methods </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2022-2', requestTime='0.03 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='91.126.68.164', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Sat Dec 03 09:50:15 UTC 2022, cacheEnabled=true}}">
#                         © 2022
#                         The Book Depository Ltd.UK.<br/>Registered company number: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div class="corner-content hidden" data-ckey-show-from="cornerContent" data-ckey-suppress="cornerContentPosting-Dates-EN" data-show-for="8760">
# <img class="corner-content-img" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/last-order-icon.svg"/>
# <a class="corner-content-link" href="/Christmas-FAQs">
# <div class="corner-content-text">
# <span class="underline-text">Christmas Posting dates here</span></div>
# </a>
# <a class="close-button" href="#"><i class="icon-close"></i></a>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Shop","bd_js_too_long_for_shipping_label":"Sorry, that's too long for our shipping labels","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Sorry, that's too long","bd_js_could_not_find_address_try_again":"Sorry, we couldn't find the address. Please try again","bd_saving_percent_off":"{0}%&lt;br&gt;off","bd_js_total_basket_count":"{0, plural, one {You have &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;item&lt;/span&gt;&lt;/b&gt; in your basket} other {You have &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;items&lt;/span&gt;&lt;/b&gt; in your basket}}","bd_js_total_cost":"Total cost: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"show less","bd_js_item_added_to_your_basket":"Item added to your basket","bd_rrp":"RRP","bd_link_prefix":"","bd_js_unable_get_address_enter_manually":"Sorry, we are unable to get the address. Please enter manually:","bd_js_keep_typing_to_refine_search_results":"Keep typing to refine the search results","bd_js_top_categories":"Top Categories","bd_price_save":"Save {0}","bd_js_name_only_letters":"Sorry, full name can only contain letters","bd_js_show_more":"show more","bd_js_enter_valid_email_address":"Please enter a valid email address","bd_js_enter_address_manually":"Enter address manually","bd_js_more_categories":"More Categories","bd_30_day_low_price_carousel":"30-day low price","bd_js_continue_shopping":"Continue Shopping","bd_js_account_and_help":"Account &amp; Help","bd_js_basket_checkout":"Basket / Checkout","bd_add_to_basket":"Add to basket","bd_js_enter_first_last_name":"Please enter a first and last name","bd_js_please_enter_your":"Please enter your"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# ![image](img\html-content-web-scraping.png)

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# ![image](img\attribute-example-for-web-scraping-1536x386.png)

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>

# %%
soup.h1
# Out:
# <h1>Bestsellers – our most popular items, updated daily.</h1>

# %%
type(soup.h1)
# Out:
# bs4.element.Tag

# %% [markdown]
# Y sí queremos solo el texto?..

# %%
soup.h1.get_text()
# Out:
# 'Bestsellers – our most popular items, updated daily.'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
soup.a
# Out:
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies Help section</a>

# %%
soup.a['href']
# Out:
# '/help/topic/HelpId/53/How-we-use-cookies#helpContent'

# %%
soup.a.get_text()
# Out:
# 'Cookies Help section'

# %%
soup.a['target']
# Out:
# '"_blank"'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar .find()")
print(soup.h1)
print("Utilizando .find()")
print(soup.find("h1"))

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
len(soup.find_all('a'))
# Out:
# 314

# %%
soup.find_all('h2')
# Out:
# [<h2>We use cookies to improve this site</h2>,
#  <h2>Are you happy to accept cookies?</h2>,
#  <h2>Cookie Preferences</h2>,
#  <h2>Essential</h2>,
#  <h2>Performance and Analytics</h2>,
#  <h2>Advertising</h2>,
#  <h2>Top Authors</h2>,
#  <h2>Bestselling Series</h2>,
#  <h2>Books By Language</h2>,
#  <h2>Filter your search</h2>]

# %%
soup.find_all('a')
# Out:
# [<a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies Help section</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>,
#  <a class="showLess" role="button">Show less</a>,
#  <a class="showMore" role="button">Show more</a>,
#  <a class="showLess" role="button">Show less</a>,
#  <a class="showMore" role="button">Show more</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookie Notice</a>,
#  <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Interest-Based Ads</a>,
#  <a class="showLess" role="button">Show less</a>,
#  <a class="showMore" role="button">Show more</a>,
#  <a class="btn btn-sm btn-secondary btn-cancel" href="#" rel="nofollow">
#                  Cancel</a>,
#  <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                  Save settings</a>,
#  <a class="home-icon-link" href="/"><i class="icon-home"></i><span class="show-non-desktop">Home</span></a>,
#  <a href="/contactus"><i class="icon-em"></i>Contact us</a>,
#  <a href="/help" rel="nofollow"><i class="icon-info"></i>Help</a>,
#  <a class="free-delivery-block" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#                                  FREE<br/>DELIVERY</a>,
#  <a class="promotion-block" href="/cyber-monday" rel="nofollow" title=""></a>,
#  <a href="/track" rel="nofollow"><i class="icon-order-status"></i>Order Status</a>,
#  <a href="/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Wishlist</a>,
#  <a href="/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Sign in/Join</a>,
#  <a class="brand-link" href="/">
#  <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/logo.svg"/>
#  </a>,
#  <a class="mobile-basket-btn basket-wrap" href="/basket">
#  <span class="item-count" data-item-count="0">0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="advanced-search" href="/search/advanced" rel="nofollow">Advanced Search</a>,
#  <a alt="Free delivery worldwide" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#  <i class="icon-rocket"></i> Free delivery worldwide</a>,
#  <a class="free-delivery-ribbon-block" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#                              FREE<br/>DELIVERY</a>,
#  <a class="promotion-ribbon-block" href="/cyber-monday" rel="nofollow" title=""></a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">Shop by category</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categories</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Children's Age Ranges</a>,
#  <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>,
#  <a>Browse All</a>,
#  <a href="/category/2/Art-Photography">
#                                          Art &amp; Photography</a>,
#  <a href="/category/3389/Audio-Books">
#                                          Audio Books</a>,
#  <a href="/category/213/Biography">
#                                          Biography</a>,
#  <a href="/category/928/Business-Finance-Law">
#                                          Business, Finance &amp; Law</a>,
#  <a href="/category/2455/Childrens-Books">
#                                          Children's Books</a>,
#  <a href="/category/1897/Computing">
#                                          Computing</a>,
#  <a href="/category/2942/Crafts-Hobbies">
#                                          Crafts &amp; Hobbies</a>,
#  <a href="/category/2616/Crime-Thriller">
#                                          Crime &amp; Thriller</a>,
#  <a href="/category/240/Dictionaries-Languages">
#                                          Dictionaries &amp; Languages</a>,
#  <a href="/category/3245/Entertainment">
#                                          Entertainment</a>,
#  <a href="/category/333/Fiction">
#                                          Fiction</a>,
#  <a href="/category/2858/Food-Drink">
#                                          Food &amp; Drink</a>,
#  <a href="/category/2633/Graphic-Novels-Anime-Manga">
#                                          Graphic Novels, Anime &amp; Manga</a>,
#  <a href="/category/2770/Health">
#                                          Health</a>,
#  <a href="/category/2638/History-Archaeology">
#                                          History &amp; Archaeology</a>,
#  <a href="/category/2892/Home-Garden">
#                                          Home &amp; Garden</a>,
#  <a href="/category/2978/Humour">
#                                          Humour</a>,
#  <a href="/category/1279/Medical">
#                                          Medical</a>,
#  <a href="/category/2819/Mind-Body-Spirit">
#                                          Mind, Body &amp; Spirit</a>,
#  <a href="/category/2985/Natural-History">
#                                          Natural History</a>,
#  <a href="/category/2802/Personal-Development">
#                                          Personal Development</a>,
#  <a href="/category/283/Poetry-Drama">
#                                          Poetry &amp; Drama</a>,
#  <a href="/category/375/Reference">
#                                          Reference</a>,
#  <a href="/category/3120/Religion">
#                                          Religion</a>,
#  <a href="/category/2630/Romance">
#                                          Romance</a>,
#  <a href="/category/1476/Science-Geography">
#                                          Science &amp; Geography</a>,
#  <a href="/category/2623/Science-Fiction-Fantasy-Horror">
#                                          Science Fiction, Fantasy &amp; Horror</a>,
#  <a href="/category/632/Society-Social-Sciences">
#                                          Society &amp; Social Sciences</a>,
#  <a href="/category/3013/Sport">
#                                          Sport</a>,
#  <a href="/category/3385/Stationery">
#                                          Stationery</a>,
#  <a href="/category/3328/Teaching-Resources-Education">
#                                          Teaching Resources &amp; Education</a>,
#  <a href="/category/1708/Technology-Engineering">
#                                          Technology &amp; Engineering</a>,
#  <a href="/category/3391/Teen-Young-Adult">
#                                          Teen &amp; Young Adult</a>,
#  <a href="/category/2967/Transport">
#                                          Transport</a>,
#  <a href="/category/3098/Travel-Holiday-Guides">
#                                          Travel &amp; Holiday Guides</a>,
#  <a href="/category/3392/Books-for-Ages-0-2">
#                                  Ages 0-2</a>,
#  <a href="/category/3393/Books-for-Ages-3-5">
#                                  Ages 3-5</a>,
#  <a href="/category/3394/Books-for-Ages-6-8">
#                                  Ages 6-8</a>,
#  <a href="/category/3395/Books-for-Ages-9-11">
#                                  Ages 9-11</a>,
#  <a href="/category/3391/Teen-Young-Adult">
#                                  Teen &amp; Young Adult</a>,
#  <a class="link-item-text-only link-item" href="/author/J-K-Rowling">
#  <div class="link-text">J. K. Rowling</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/roald-dahl">
#  <div class="link-text">Roald Dahl</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/julia-donaldson">
#  <div class="link-text">Julia Donaldson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/stephen-king">
#  <div class="link-text">Stephen King</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/david-walliams">
#  <div class="link-text">David Walliams</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/Dr-Seuss">
#  <div class="link-text">Dr. Seuss</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/andy-griffiths">
#  <div class="link-text">Andy Griffiths</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/James-Patterson">
#  <div class="link-text">James Patterson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/Sarah-J-Maas">
#  <div class="link-text">Sarah J. Maas</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/enid-blyton">
#  <div class="link-text">Enid Blyton</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/john-green">
#  <div class="link-text">John Green</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/Brandon-Sanderson">
#  <div class="link-text">Brandon Sanderson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/popular-authors">
#  <div class="link-text">See all</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/harry-potter">
#  <div class="link-text">Harry Potter</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/game-of-thrones">
#  <div class="link-text">Game Of Thrones</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/lego">
#  <div class="link-text">Lego</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/divergent-trilogy">
#  <div class="link-text">Divergent</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/search/advanced?seriesId=478050">
#  <div class="link-text">Throne Of Glass</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/star-wars">
#  <div class="link-text">Star Wars</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/spanish">
#  <div class="link-text">Books in Spanish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/polish-books">
#  <div class="link-text">Books in Polish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/german-books">
#  <div class="link-text">Books in German</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/french-books">
#  <div class="link-text">Books in French</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/languages">
#  <div class="link-text">Languages Bookshop</div>
#  </a>,
#  <a href="/bestsellers">Bestsellers</a>,
#  <a href="/top-new-releases">New Releases</a>,
#  <a href="/Christmas-FAQs">
#                              Christmas FAQs</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">
#          English</a>,
#  <a class="global-nav-close" href="#"><i class="icon-close"></i></a>,
#  <a class="language-option" data-value="en_US" href="#">
#                              English</a>,
#  <a class="language-option" data-value="es_ES" href="#">
#                              Spanish (Español)</a>,
#  <a class="basket-btn" href="/basket" rel="nofollow">
#  <span class="item-count">
#                          0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filter your search">Filter your search</a>,
#  <a>1</a>,
#  <a href="/bestsellers?page=2">2</a>,
#  <a href="/bestsellers?page=3">3</a>,
#  <a href="/bestsellers?page=4">4</a>,
#  <a href="/bestsellers?page=5">5</a>,
#  <a href="/bestsellers?page=2">»</a>,
#  <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
#  <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
#  </a>,
#  <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                      It Ends With Us: The most heartbreaking novel you'll ever read<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471156267" data-price="12.84" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Verity-Colleen-Hoover/9781408726600" itemprop="url">
#  <img alt="Verity" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
#  </a>,
#  <a href="/Verity-Colleen-Hoover/9781408726600">
#                      Verity<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Verity" href="/Verity-Colleen-Hoover/9781408726600">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408726600" data-price="11.94" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581" itemprop="url">
#  <img alt="Before the Coffee Gets Cold" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5290/9781529029581.jpg"/>
#  </a>,
#  <a href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#                      Before the Coffee Gets Cold<br/>
#  </a>,
#  <a href="/author/Toshikazu-Kawaguchi" itemprop="author">Toshikazu Kawaguchi</a>,
#  <a aria-label="Ratings for Before the Coffee Gets Cold" href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529029581" data-price="14.15" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781529029581" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
#  <img alt="Atomic Habits" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
#  </a>,
#  <a href="/Atomic-Habits-James-Clear/9781847941831">
#                      Atomic Habits<br/>
#  </a>,
#  <a href="/author/James-Clear" itemprop="author">James Clear</a>,
#  <a aria-label="Ratings for Atomic Habits" href="/Atomic-Habits-James-Clear/9781847941831">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781847941831" data-price="20.68" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Tools-Phil-Stutz/9780812983043" itemprop="url">
#  <img alt="The Tools" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/8129/9780812983043.jpg"/>
#  </a>,
#  <a href="/Tools-Phil-Stutz/9780812983043">
#                      The Tools<br/>
#  </a>,
#  <a href="/author/Phil-Stutz" itemprop="author">Phil Stutz</a>,
#  <a aria-label="Ratings for The Tools" href="/Tools-Phil-Stutz/9780812983043">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780812983043" data-price="20.11" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780812983043" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697" itemprop="url">
#  <img alt="Seven Husbands of Evelyn Hugo" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515697.jpg"/>
#  </a>,
#  <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#                      Seven Husbands of Evelyn Hugo<br/>
#  </a>,
#  <a href="/author/Taylor-Jenkins-Reid" itemprop="author">Taylor Jenkins Reid</a>,
#  <a aria-label="Ratings for Seven Husbands of Evelyn Hugo" href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515697" data-price="12.89" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781398515697" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555" itemprop="url">
#  <img alt="Roald Dahl's Marvellous Joke Book" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1413/9780141340555.jpg"/>
#  </a>,
#  <a href="/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555">
#                      Roald Dahl's Marvellous Joke Book<br/>
#  </a>,
#  <a href="/author/Roald-Dahl" itemprop="author">Roald Dahl</a>,
#  <a aria-label="Ratings for Roald Dahl's Marvellous Joke Book" href="/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141340555" data-price="20.78" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780141340555" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Letters-from-M-M-Paris-Paul-McNeil/9780500025277" itemprop="url">
#  <img alt="Letters from M/M (Paris)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5000/9780500025277.jpg"/>
#  <div class="savings-splat">
#                          13%<br/>off</div>
#  </a>,
#  <a href="/Letters-from-M-M-Paris-Paul-McNeil/9780500025277">
#                      Letters from M/M (Paris)<br/>
#  </a>,
#  <a href="/author/Paul-McNeil" itemprop="author">Paul McNeil</a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780500025277" data-price="53.78" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780500025277" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Midnight-Library-Matt-Haig/9781786892737" itemprop="url">
#  <img alt="The Midnight Library" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7868/9781786892737.jpg"/>
#  </a>,
#  <a href="/Midnight-Library-Matt-Haig/9781786892737">
#                      The Midnight Library<br/>
#  </a>,
#  <a href="/author/Matt-Haig" itemprop="author">Matt Haig</a>,
#  <a aria-label="Ratings for The Midnight Library" href="/Midnight-Library-Matt-Haig/9781786892737">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781786892737" data-price="13.18" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781786892737" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Undaunted-Stalingrad-Trevor-Benjamin/9781472852670" itemprop="url">
#  <img alt="Undaunted: Stalingrad" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4728/9781472852670.jpg"/>
#  <div class="savings-splat">
#                          7%<br/>off</div>
#  </a>,
#  <a href="/Undaunted-Stalingrad-Trevor-Benjamin/9781472852670">
#                      Undaunted: Stalingrad<br/>
#  </a>,
#  <a href="/author/Trevor-Benjamin" itemprop="author">Trevor Benjamin</a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781472852670" data-price="105.67" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781472852670" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Where-Crawdads-Sing-Delia-Owens/9781472154668" itemprop="url">
#  <img alt="Where the Crawdads Sing" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4721/9781472154668.jpg"/>
#  <div class="savings-splat">
#                          5%<br/>off</div>
#  </a>,
#  <a href="/Where-Crawdads-Sing-Delia-Owens/9781472154668">
#                      Where the Crawdads Sing<br/>
#  </a>,
#  <a href="/author/Delia-Owens" itemprop="author">Delia Owens</a>,
#  <a aria-label="Ratings for Where the Crawdads Sing" href="/Where-Crawdads-Sing-Delia-Owens/9781472154668">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781472154668" data-price="12.82" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781472154668" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491" itemprop="url">
#  <img alt="Brain Games For Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780552491.jpg"/>
#  </a>,
#  <a href="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491">
#                      Brain Games For Clever Kids (R)<br/>
#  </a>,
#  <a href="/author/Gareth-Moore" itemprop="author">Gareth Moore</a>,
#  <a aria-label="Ratings for Brain Games For Clever Kids (R)" href="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781780552491" data-price="9.14" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781780552491" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Secret-History-Donna-Tartt/9780140167771" itemprop="url">
#  <img alt="The Secret History" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1401/9780140167771.jpg"/>
#  </a>,
#  <a href="/Secret-History-Donna-Tartt/9780140167771">
#                      The Secret History<br/>
#  </a>,
#  <a href="/author/Donna-Tartt" itemprop="author">Donna Tartt</a>,
#  <a aria-label="Ratings for The Secret History" href="/Secret-History-Donna-Tartt/9780140167771">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780140167771" data-price="15.36" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780140167771" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Body-Keeps-Score-Bessel-Van-Der-Kolk/9780141978611" itemprop="url">
#  <img alt="The Body Keeps the Score" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1419/9780141978611.jpg"/>
#  </a>,
#  <a href="/Body-Keeps-Score-Bessel-Van-Der-Kolk/9780141978611">
#                      The Body Keeps the Score<br/>
#  </a>,
#  <a href="/author/Bessel-Van-Der-Kolk" itemprop="author">Bessel Van Der Kolk</a>,
#  <a aria-label="Ratings for The Body Keeps the Score" href="/Body-Keeps-Score-Bessel-Van-Der-Kolk/9780141978611">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141978611" data-price="17.57" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780141978611" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-5-Special-Edition-Mo-Xiang-Tong-Xiu/9781685798406" itemprop="url">
#  <img alt="Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 5 (Special Edition)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/6857/9781685798406.jpg"/>
#  </a>,
#  <a href="/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-5-Special-Edition-Mo-Xiang-Tong-Xiu/9781685798406">
#                      Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 5 (Special Edition)<br/>
#  </a>,
#  <a href="/author/Mo-Xiang-Tong-Xiu" itemprop="author">Mo Xiang Tong Xiu;</a>,
#  <a aria-label="Ratings for Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 5 (Special Edition)" href="/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-5-Special-Edition-Mo-Xiang-Tong-Xiu/9781685798406">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781685798406" data-price="28.50" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781685798406" rel="nofollow">
#                          Pre-order</a>,
#  <a href="/Thursday-Murder-Club-Richard-Osman/9780241988268" itemprop="url">
#  <img alt="The Thursday Murder Club" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2419/9780241988268.jpg"/>
#  </a>,
#  <a href="/Thursday-Murder-Club-Richard-Osman/9780241988268">
#                      The Thursday Murder Club<br/>
#  </a>,
#  <a href="/author/Richard-Osman" itemprop="author">Richard Osman</a>,
#  <a aria-label="Ratings for The Thursday Murder Club" href="/Thursday-Murder-Club-Richard-Osman/9780241988268">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241988268" data-price="14.08" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780241988268" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Surrender-Bono/9781529151787" itemprop="url">
#  <img alt="Surrender" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5291/9781529151787.jpg"/>
#  <div class="savings-splat">
#                          6%<br/>off</div>
#  </a>,
#  <a href="/Surrender-Bono/9781529151787">
#                      Surrender<br/>
#  </a>,
#  <a href="/author/Bono" itemprop="author">Bono</a>,
#  <a aria-label="Ratings for Surrender" href="/Surrender-Bono/9781529151787">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529151787" data-price="29.50" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781529151787" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-4-Mo-Xiang-Tong-Xiu/9781638583011" itemprop="url">
#  <img alt="Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 4" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/6385/9781638583011.jpg"/>
#  </a>,
#  <a href="/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-4-Mo-Xiang-Tong-Xiu/9781638583011">
#                      Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 4<br/>
#  </a>,
#  <a href="/author/Mo-Xiang-Tong-Xiu" itemprop="author">Mo Xiang Tong Xiu</a>,
#  <a aria-label="Ratings for Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 4" href="/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-4-Mo-Xiang-Tong-Xiu/9781638583011">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781638583011" data-price="21.93" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781638583011" rel="nofollow">
#                          Pre-order</a>,
#  <a href="/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824" itemprop="url">
#  <img alt="I'm Glad My Mom Died" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9821/9781982185824.jpg"/>
#  <div class="savings-splat">
#                          20%<br/>off</div>
#  </a>,
#  <a href="/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824">
#                      I'm Glad My Mom Died<br/>
#  </a>,
#  <a href="/author/Jennette-McCurdy" itemprop="author">Jennette McCurdy</a>,
#  <a aria-label="Ratings for I'm Glad My Mom Died" href="/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781982185824" data-price="24.89" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781982185824" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Small-Things-Like-These-Claire-Keegan/9780571368709" itemprop="url">
#  <img alt="Small Things Like These" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5713/9780571368709.jpg"/>
#  </a>,
#  <a href="/Small-Things-Like-These-Claire-Keegan/9780571368709">
#                      Small Things Like These<br/>
#  </a>,
#  <a href="/author/Claire-Keegan" itemprop="author">Claire Keegan</a>,
#  <a aria-label="Ratings for Small Things Like These" href="/Small-Things-Like-These-Claire-Keegan/9780571368709">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780571368709" data-price="13.30" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780571368709" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Seven-Moons-Maali-Almeida-Shehan-Karunatilaka/9781908745903" itemprop="url">
#  <img alt="The Seven Moons of Maali Almeida" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9087/9781908745903.jpg"/>
#  </a>,
#  <a href="/Seven-Moons-Maali-Almeida-Shehan-Karunatilaka/9781908745903">
#                      The Seven Moons of Maali Almeida<br/>
#  </a>,
#  <a href="/author/Shehan-Karunatilaka" itemprop="author">Shehan Karunatilaka</a>,
#  <a aria-label="Ratings for The Seven Moons of Maali Almeida" href="/Seven-Moons-Maali-Almeida-Shehan-Karunatilaka/9781908745903">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781908745903" data-price="22.13" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781908745903" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Light-We-Carry-Michelle-Obama/9780241621240" itemprop="url">
#  <img alt="The Light We Carry" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2416/9780241621240.jpg"/>
#  <div class="savings-splat">
#                          11%<br/>off</div>
#  </a>,
#  <a href="/Light-We-Carry-Michelle-Obama/9780241621240">
#                      The Light We Carry<br/>
#  </a>,
#  <a href="/author/Michelle-Obama" itemprop="author">Michelle Obama</a>,
#  <a aria-label="Ratings for The Light We Carry" href="/Light-We-Carry-Michelle-Obama/9780241621240">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241621240" data-price="27.96" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780241621240" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Taste-Stanley-Tucci/9780241501009" itemprop="url">
#  <img alt="Taste" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2415/9780241501009.jpg"/>
#  </a>,
#  <a href="/Taste-Stanley-Tucci/9780241501009">
#                      Taste<br/>
#  </a>,
#  <a href="/author/Stanley-Tucci" itemprop="author">Stanley Tucci</a>,
#  <a aria-label="Ratings for Taste" href="/Taste-Stanley-Tucci/9780241501009">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241501009" data-price="15.79" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780241501009" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Good-Girls-Guide-Murder-Holly-Jackson/9781405293181" itemprop="url">
#  <img alt="A Good Girl's Guide to Murder" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4052/9781405293181.jpg"/>
#  </a>,
#  <a href="/Good-Girls-Guide-Murder-Holly-Jackson/9781405293181">
#                      A Good Girl's Guide to Murder<br/>
#  </a>,
#  <a href="/author/Holly-Jackson" itemprop="author">Holly Jackson</a>,
#  <a aria-label="Ratings for A Good Girl's Guide to Murder" href="/Good-Girls-Guide-Murder-Holly-Jackson/9781405293181">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781405293181" data-price="13.57" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781405293181" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/World-Simon-Sebag-Montefiore/9780297869672" itemprop="url">
#  <img alt="The World" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2978/9780297869672.jpg"/>
#  </a>,
#  <a href="/World-Simon-Sebag-Montefiore/9780297869672">
#                      The World<br/>
#  </a>,
#  <a href="/author/Simon-Sebag-Montefiore" itemprop="author">Simon Sebag Montefiore</a>,
#  <a aria-label="Ratings for The World" href="/World-Simon-Sebag-Montefiore/9780297869672">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780297869672" data-price="42.88" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780297869672" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Twisted-Love-Ana-Huang/9780349434278" itemprop="url">
#  <img alt="Twisted Love" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349434278.jpg"/>
#  </a>,
#  <a href="/Twisted-Love-Ana-Huang/9780349434278">
#                      Twisted Love<br/>
#  </a>,
#  <a href="/author/Ana-Huang" itemprop="author">Ana Huang</a>,
#  <a aria-label="Ratings for Twisted Love" href="/Twisted-Love-Ana-Huang/9780349434278">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349434278" data-price="13.10" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780349434278" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Diary-Wimpy-Kid-Diper-OEverloede-Book-17-Jeff-Kinney/9780241583081" itemprop="url">
#  <img alt="Diary of a Wimpy Kid: Diper OEverloede (Book 17)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2415/9780241583081.jpg"/>
#  </a>,
#  <a href="/Diary-Wimpy-Kid-Diper-OEverloede-Book-17-Jeff-Kinney/9780241583081">
#                      Diary of a Wimpy Kid: Diper OEverloede (Book 17)<br/>
#  </a>,
#  <a href="/author/Jeff-Kinney" itemprop="author">Jeff Kinney</a>,
#  <a aria-label="Ratings for Diary of a Wimpy Kid: Diper OEverloede (Book 17)" href="/Diary-Wimpy-Kid-Diper-OEverloede-Book-17-Jeff-Kinney/9780241583081">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241583081" data-price="17.14" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780241583081" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Just-One-Thing-Dr-Michael-Mosley/9781780725512" itemprop="url">
#  <img alt="Just One Thing" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7807/9781780725512.jpg"/>
#  <div class="savings-splat">
#                          16%<br/>off</div>
#  </a>,
#  <a href="/Just-One-Thing-Dr-Michael-Mosley/9781780725512">
#                      Just One Thing<br/>
#  </a>,
#  <a href="/author/Dr-Michael-Mosley" itemprop="author">Dr Michael Mosley</a>,
#  <a aria-label="Ratings for Just One Thing" href="/Just-One-Thing-Dr-Michael-Mosley/9781780725512">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/help/topic/HelpId/RRP#helpContent">
#                                          RRP</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/lowestprice#helpContent">
#                                          30-day low price</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781780725512" data-price="17.88" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781780725512" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Ugly-Love-Colleen-Hoover/9781471136726" itemprop="url">
#  <img alt="Ugly Love" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471136726.jpg"/>
#  </a>,
#  <a href="/Ugly-Love-Colleen-Hoover/9781471136726">
#                      Ugly Love<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Ugly Love" href="/Ugly-Love-Colleen-Hoover/9781471136726">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471136726" data-price="13.15" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471136726" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532" itemprop="url">
#  <img alt="They Know Not What They Do" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7860/9781786073532.jpg"/>
#  </a>,
#  <a href="/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532">
#                      They Know Not What They Do<br/>
#  </a>,
#  <a href="/author/Jussi-Valtonen" itemprop="author">Jussi Valtonen</a>,
#  <a aria-label="Ratings for They Know Not What They Do" href="/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781786073532" data-price="14.41" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781786073532" rel="nofollow">
#                          Add to basket</a>,
#  <a>1</a>,
#  <a href="/bestsellers?page=2">2</a>,
#  <a href="/bestsellers?page=3">3</a>,
#  <a href="/bestsellers?page=4">4</a>,
#  <a href="/bestsellers?page=5">5</a>,
#  <a href="/bestsellers?page=2">»</a>,
#  <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-fb"></i>
#  </a>,
#  <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-tw"></i>
#  </a>,
#  <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-pi"></i>
#  </a>,
#  <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-in"></i>
#  </a>,
#  <a href="/about-us" rel="nofollow">
#                              About us</a>,
#  <a href="/sitemap">
#                              Sitemap</a>,
#  <a href="/bookmarks">
#                              Bookmarks</a>,
#  <a class="footer-sign-in-link" href="/account/login/to/account">
#                                      Sign in/Join</a>,
#  <a href="/help" rel="nofollow">
#                                  Help</a>,
#  <a href="/contactus">
#                                  Contact us</a>,
#  <a href="/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                  Where's my stuff?</a>,
#  <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                  Where do you deliver?</a>,
#  <a href="/cancelorder" rel="nofollow">
#                                  Cancel my order</a>,
#  <a href="/help/topic/HelpId/30#helpContent" rel="nofollow">
#                                  Return my order</a>,
#  <a href="/affiliate">
#                              Affiliates</a>,
#  <a href="/jobs">
#                              Jobs</a>,
#  <a href="/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                  Complaints</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                  Cookies</a>,
#  <a href="/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                  Privacy policy</a>,
#  <a href="/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                  Terms &amp; Conditions</a>,
#  <a class="footer-sign-in-link" href="/account/login/to/account" rel="nofollow">
#                                      Sign in/Join</a>,
#  <a href="/track">
#                              Order Status</a>,
#  <a href="/contactus">
#                              Contact us</a>,
#  <a href="/help">
#                              Help</a>,
#  <a href="/about-us" rel="nofollow">
#                              About us</a>,
#  <a href="/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                              Terms &amp; Conditions</a>,
#  <a href="/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                              Privacy policy</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                              Cookies</a>,
#  <a class="corner-content-link" href="/Christmas-FAQs">
#  <div class="corner-content-text">
#  <span class="underline-text">Christmas Posting dates here</span></div>
#  </a>,
#  <a class="close-button" href="#"><i class="icon-close"></i></a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
# Out:
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies Help section</a>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>
# <a class="showLess" role="button">Show less</a>
# <a class="showMore" role="button">Show more</a>
# <a class="showLess" role="button">Show less</a>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 30 libros con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - book titles
# - formats (paperback or hardback)
# - publication dates
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los titulos de los libros (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un libro y elegimos inspeccionar)

# %% [markdown]
# title

# %%
all_h3 = soup.find_all("h3", class_="title")
for h3 in all_h3:
       print(h3.get_text(strip=True))
# Out:
# It Ends With Us: The most heartbreaking novel you'll ever read
# Verity
# Before the Coffee Gets Cold
# Atomic Habits
# The Tools
# Seven Husbands of Evelyn Hugo
# Roald Dahl's Marvellous Joke Book
# Letters from M/M (Paris)
# The Midnight Library
# Undaunted: Stalingrad
# Where the Crawdads Sing
# Brain Games For Clever Kids (R)
# The Secret History
# The Body Keeps the Score
# Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 5 (Special Edition)
# The Thursday Murder Club
# Surrender
# Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 4
# I'm Glad My Mom Died
# Small Things Like These
# The Seven Moons of Maali Almeida
# The Light We Carry
# Taste
# A Good Girl's Guide to Murder
# The World
# Twisted Love
# Diary of a Wimpy Kid: Diper OEverloede (Book 17)
# Just One Thing
# Ugly Love
# They Know Not What They Do

# %% [markdown]
# ## Tips importantes

# %% [markdown]
# soup.find_all(“h3”) encuentra cada elemento h3 en la página web; con class_=”title” especificamos que buscamos específicamente etiquetas h3 que contengan el atributo class_=”title” (nota importante: el “_” en class**__**=”title” no es un error tipográfico, se requiere en Beautiful Soup cuando seleccionando atributos de clase).

# %% [markdown]
# Guardamos los elementos h3 en all_h3, que se comporta como una lista, por lo que podemos recorrerlos con un bucle for. En cada iteración extraemos solo el texto del elemento h3 con .get_text(), y con el parámetro strip=True nos aseguramos de eliminar cualquier espacio en blanco innecesario.

# %% [markdown]
# ## Obtener los formatos de los libros

# %% [markdown]
# Del paso anterior tenemos todos los títulos de libros de la página de los más vendidos. Pero, ¿qué sabemos acerca de sus formatos? ¿Hay más libros de tapa dura o tapa blanda?
#
# Averigüémoslo inspeccionando el elemento de formato de libro:

# %% [markdown]
# Como siempre inspeccionamos y buscamos el formato..

# %% [markdown]
# Y como queremos saber la cantidad de cada formato lo metemos en dataframe

# %% [markdown]
# div.item-info p.format

# %%
formats = soup.find_all("p",class_="format") # div y p son etiquetas donde se encuentran
formats_series = pd.Series(formats)
formats_series.value_counts()
# Out:
# [Paperback]    21
# [Hardback]      8
# [Game]          1
# dtype: int64

# %% [markdown]
# ## Obtener las fechas de publicación (find_all + get_text)

# %% [markdown]
# Al igual que antes inspeccionamos....

# %% [markdown]
# published

# %%
fechas = soup.find_all("p",class_="published")
anios = []
for fecha in fechas:
    fecha_completa = fecha.get_text()
    #anio = fecha_completa[-4:]
    anio = fecha_completa.split(" ")[-1]
    anios.append(anio)
dates_series = pd.Series(anios)
dates_series.value_counts()
# Out:
# 2022    12
# 2019     3
# 2021     3
# 2023     3
# 2016     2
# 2018     2
# 2014     2
# 2012     1
# 1995     1
# 2015     1
# dtype: int64

# %%
dates = soup.find_all("p", class_="published")
dates = [date.get_text()[-4:] for date in dates] #con esta list comprehension obtenemos solo el año
dates_series = pd.Series(dates)
dates_series.value_counts()
# Out:
# 2022    12
# 2019     3
# 2021     3
# 2023     3
# 2016     2
# 2018     2
# 2014     2
# 2012     1
# 1995     1
# 2015     1
# dtype: int64

# %% [markdown]
# ## Obtener los precios (find_all + get_text)

# %% [markdown]
# Inspeccionamos..

# %% [markdown]
# price

# %%
prices = soup.find_all("span", class_="sale-price")

# %%
print(prices)
# Out:
# [<span class="sale-price">12,84 €</span>, <span class="sale-price">11,94 €</span>, <span class="sale-price">14,15 €</span>, <span class="sale-price">20,68 €</span>, <span class="sale-price">20,11 €</span>, <span class="sale-price">12,89 €</span>, <span class="sale-price">20,78 €</span>, <span class="sale-price">53,78 €</span>, <span class="sale-price">13,18 €</span>, <span class="sale-price">105,67 €</span>, <span class="sale-price">12,82 €</span>, <span class="sale-price">9,14 €</span>, <span class="sale-price">15,36 €</span>, <span class="sale-price">17,57 €</span>, <span class="sale-price">28,50 €</span>, <span class="sale-price">14,08 €</span>, <span class="sale-price">29,50 €</span>, <span class="sale-price">21,93 €</span>, <span class="sale-price">24,89 €</span>, <span class="sale-price">13,30 €</span>, <span class="sale-price">22,13 €</span>, <span class="sale-price">27,96 €</span>, <span class="sale-price">15,79 €</span>, <span class="sale-price">13,57 €</span>, <span class="sale-price">42,88 €</span>, <span class="sale-price">13,10 €</span>, <span class="sale-price">17,14 €</span>, <span class="sale-price">17,88 €</span>, <span class="sale-price">13,15 €</span>, <span class="sale-price">14,41 €</span>]

# %%
prices[0]
# Out:
# <span class="sale-price">12,84 €</span>

# %%
precio = prices[0].get_text().split(' ')[0].replace(',','.')
precio
# Out:
# '12.84'

# %%
# Ejercicio en clase: Calcular la media de precio

precios_float = []
prices = soup.find_all("span", class_="sale-price")
for precio in prices:
    precio_f = float(precio.get_text().split(' ')[0].replace(',','.'))
    precios_float.append(precio_f)

# Numpy
import numpy as np
print(np.mean(precios_float))

# Pandas
print(pd.Series(precios_float).mean())
# Out:
# 22.37066666666666
# 22.37066666666666

# %%
prices = soup.find_all("span", class_="sale-price")
todoprecios = pd.DataFrame(prices)
todoprecios = todoprecios.rename({0:'precio'},axis=1)
todoprecios['precio'] = todoprecios['precio'].str.replace("€","").str.replace(",", ".").astype(float)

#todoprecios.info()

todoprecios.precio.mean()
#todoprecios.mean()
# Out:
# 22.37066666666666

# %%
float(precio)
# Out:
# 12.84

# %%
prices[5].get_text(strip=True).split(' ')

# %%
# final_prices = []
# for price in prices:
#       original_price = price.find("span", class_="rrp")
#       if original_price:
#              current_price = str(original_price.previousSibling).strip() # nos quedamos solo con el numero sin etiquetas
#              current_price = float(current_price.split("€")[0].replace(",", ".")) # quitamos el signo de euro y reemplazamos la coma por el punto para que python lo reconozca con float
#              final_prices.append(current_price)
#       else:
#              current_price = float(price.get_text(strip=True).split("€")[0].replace(",", "."))
#              final_prices.append(current_price)
# print(final_prices)

# %% [markdown]
# ## Recolectar información de un libro

# %% [markdown]
# Primero creamos un soup en la pagína 'principal'

# %%
libros = soup.find_all(class_='item-img')

# %% [markdown]
# Guardamos en una variable la url principal

# %%
url_principal = 'https://www.bookdepository.com'

# %%
libros[0]
# Out:
# <div class="item-img">
# <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
# <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
# </a>
# </div>

# %% [markdown]
# Creamos una lista con los urls de los libros

# %%
lista_URLs = []
for libro in libros:
    etiqueta_a = libro.find('a')
    URL_libro = etiqueta_a['href']
    lista_URLs.append(url_principal+URL_libro)

lista_URLs
# Out:
# ['https://www.bookdepository.com/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267',
#  'https://www.bookdepository.com/Verity-Colleen-Hoover/9781408726600',
#  'https://www.bookdepository.com/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581',
#  'https://www.bookdepository.com/Atomic-Habits-James-Clear/9781847941831',
#  'https://www.bookdepository.com/Tools-Phil-Stutz/9780812983043',
#  'https://www.bookdepository.com/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697',
#  'https://www.bookdepository.com/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555',
#  'https://www.bookdepository.com/Letters-from-M-M-Paris-Paul-McNeil/9780500025277',
#  'https://www.bookdepository.com/Midnight-Library-Matt-Haig/9781786892737',
#  'https://www.bookdepository.com/Undaunted-Stalingrad-Trevor-Benjamin/9781472852670',
#  'https://www.bookdepository.com/Where-Crawdads-Sing-Delia-Owens/9781472154668',
#  'https://www.bookdepository.com/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491',
#  'https://www.bookdepository.com/Secret-History-Donna-Tartt/9780140167771',
#  'https://www.bookdepository.com/Body-Keeps-Score-Bessel-Van-Der-Kolk/9780141978611',
#  'https://www.bookdepository.com/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-5-Special-Edition-Mo-Xiang-Tong-Xiu/9781685798406',
#  'https://www.bookdepository.com/Thursday-Murder-Club-Richard-Osman/9780241988268',
#  'https://www.bookdepository.com/Surrender-Bono/9781529151787',
#  'https://www.bookdepository.com/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-4-Mo-Xiang-Tong-Xiu/9781638583011',
#  'https://www.bookdepository.com/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824',
#  'https://www.bookdepository.com/Small-Things-Like-These-Claire-Keegan/9780571368709',
#  'https://www.bookdepository.com/Seven-Moons-Maali-Almeida-Shehan-Karunatilaka/9781908745903',
#  'https://www.bookdepository.com/Light-We-Carry-Michelle-Obama/9780241621240',
#  'https://www.bookdepository.com/Taste-Stanley-Tucci/9780241501009',
#  'https://www.bookdepository.com/Good-Girls-Guide-Murder-Holly-Jackson/9781405293181',
#  'https://www.bookdepository.com/World-Simon-Sebag-Montefiore/9780297869672',
#  'https://www.bookdepository.com/Twisted-Love-Ana-Huang/9780349434278',
#  'https://www.bookdepository.com/Diary-Wimpy-Kid-Diper-OEverloede-Book-17-Jeff-Kinney/9780241583081',
#  'https://www.bookdepository.com/Just-One-Thing-Dr-Michael-Mosley/9781780725512',
#  'https://www.bookdepository.com/Ugly-Love-Colleen-Hoover/9781471136726',
#  'https://www.bookdepository.com/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532']

# %% [markdown]
# Vamos a analizar el url de un libro primero

# %%
lista_URLs[11]
# Out:
# 'https://www.bookdepository.com/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491'

# %%
# Hacemos un nuevo request para el primer libro: 
r = requests.get(lista_URLs[11])

# Creamos una sopa específica con la info de cada libro
soup_libro = bs(r.text, "lxml")

# %% [markdown]
# creamos un soup del primer libro

# %%
soup_libro
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="Book Depository is the world's most international online bookstore offering over 20 million books with free delivery worldwide. " name="description"/>
# <meta content="books,free,delivery,worldwide,book,offers,bestsellers,coming soon" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <title>
# 	Free delivery worldwide on all books from Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# </head>
# <body class="seasonal-theme-xmas">
# <div aria-describedby="bd_cookie_consent_popup_text" aria-labelledby="bd_cookie_consent_popup_hd1" class="cookie-consent" role="alertdialog">
# <div class="cookie-consent-content">
# <h2>We use cookies to improve this site</h2>
# <p>Cookies are used to provide, analyse and improve our services; provide chat tools; and show<br/>you relevant content on advertising. To learn more about our use of cookies, read our <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies Help section</a></p><h2>Are you happy to accept cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <button class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Accept cookies</button>
# <button class="btn btn-sm btn-secondary btn-manage" href="#" rel="nofollow">
#                 Manage cookies</button>
# </div>
# </div>
# <div class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Cookie Preferences</h2>
# <p>We use cookies and similar tools that are necessary to enable you to make purchases, including those used by approved third parties (collectively, "cookies") for the purposes described below.
#      <br/>You can learn more about how we (plus approved third parties) use cookies and how to change your settings by visiting the <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>. The choices you make here will apply to your interaction with this service on this device.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Essential</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>We use cookies to provide our services, </span>
# <div>
# <div class="additionalInfo wrapping-space"> for example, to keep track of items stored in your shopping basket, prevent fraudulent activity, improve the security of our services, keep track of your specific preferences (such as currency or language preferences), and display features, products and services that might be of interest to you. Because we use cookies to provide you our services, they cannot be disabled when used for these purposes.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Performance and Analytics</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="performanceCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to understand how customers use our services</span>
# <div>
# <div class="additionalInfo wrapping-space"> (for example, by measuring site visits) so we can make improvements. We use cookies to conduct research and diagnostics to improve our content, products and services, and to measure and analyse the performance of our services.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Advertising</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to complement your shopping experience, as described in our <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookie Notice</a></span>
# <div>
# <div class="additionalInfo wrapping-space"> and serve you certain types of ads relevant to your interests on Book Depository. This includes using third party cookies for the purpose of displaying and measuring ads (see the <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Interest-Based Ads</a> notice for how we use cookies in serving interest-based ads), measuring the effectiveness of ads, and as necessary for the third party to perform services on behalf of Book Depository.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <a class="btn btn-sm btn-secondary btn-cancel" href="#" rel="nofollow">
#                 Cancel</a>
# <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Save settings</a>
# </div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/"><i class="icon-home"></i><span class="show-non-desktop">Home</span></a></li>
# <li class="mob-nav-account"><a href="/contactus"><i class="icon-em"></i>Contact us</a></li>
# <li class="mob-nav-account"><a href="/help" rel="nofollow"><i class="icon-info"></i>Help</a></li>
# </ul>
# <div class="middle-nav">
# <div class="two-part-banner cyber-week">
# <a class="free-delivery-block" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#                                 FREE<br/>DELIVERY</a>
# <a class="promotion-block" href="/cyber-monday" rel="nofollow" title=""></a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/track" rel="nofollow"><i class="icon-order-status"></i>Order Status</a>
# </li>
# <li class="mob-nav-account"><a href="/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Wishlist</a>
# </li>
# <li class="mob-nav-account"><a href="/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Sign in/Join</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Search for books by keyword / title / author / ISBN" class="text-input" name="searchTerm" placeholder="Search for books by keyword / title / author / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Search</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/search/advanced" rel="nofollow">Advanced Search</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Free delivery worldwide" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="two-part-ribbon cyber-week">
# <a class="free-delivery-ribbon-block" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#                             FREE<br/>DELIVERY</a>
# <a class="promotion-ribbon-block" href="/cyber-monday" rel="nofollow" title=""></a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Shop by category</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categories</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Children's Age Ranges</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 All Categories</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Browse All</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Children's books by age range</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/bestsellers">Bestsellers</a></li>
# <li class="mob-nav-shop"><a href="/top-new-releases">New Releases</a>
# </li>
# <li class="mob-nav-shop">
# <a href="/Christmas-FAQs">
#                             Christmas FAQs</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         English</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Languages</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             English</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Spanish (Español)</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="English">
# <select id="selectLanguage" name="selectLanguage">
# <option selected="selected" value="en_US">
#                     English</option>
# <option value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="content-wrap">
# <div onclick="void(0);">
# <div class="main-content no-borders book-page full-width">
# <ol class="breadcrumb">
# <li class="title">Categories:</li>
# <li>
# <a href="/category/810/Primary-Middle-Schools">
#                                             Primary &amp; Middle Schools</a>
# </li>
# <li>
# <a href="/category/3355/Primary-Middle-Schools">
#                                             Primary &amp; Middle Schools</a>
# </li>
# <li>
# <a href="/category/820/Open-Learning-Home-Learning-Distance-Education">
#                                             Open Learning, Home Learning, Distance Education</a>
# </li>
# <li>
# <a href="/category/3365/Open-Learning-Home-Learning-Distance-Education">
#                                             Open Learning, Home Learning, Distance Education</a>
# </li>
# <li>
# <a href="/category/2540/Childrens-Hobby-Gaming-Books">
#                                             Children's Hobby &amp; Gaming Books</a>
# </li>
# <li>
# <a class="active" href="/category/2541/Puzzle-Books">
#                                             Puzzle Books</a>
# </li>
# </ol>
# <div class="item-wrap" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-block">
# <meta content="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491" itemprop="url"/>
# <span itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="http://schema.org/InStock" itemprop="availability"/>
# <meta content="http://schema.org/NewCondition" itemprop="itemCondition"/>
# </span>
# <div class="item-img">
# <i class="icon-mobile-zoom"></i>
# <div class="item-img-content">
# <img alt="Brain Games For Clever Kids (R)" class="book-img" itemprop="image" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/7805/9781780552491.jpg"/>
# </div>
# <div class="copy-content visible-md" data-target=".social-wrap"></div>
# </div>
# <div class="item-info">
# <h1 itemprop="name">Brain Games For Clever Kids (R)</h1>
# <div class="rating-wrap hidden-md" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <a href="#rating-distribution">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# <span itemprop="ratingValue">
#                             4.26</span>
# <span class="rating-count">
#                             (163 ratings by Goodreads)
# </span>
# <meta content="163" itemprop="ratingCount"/>
# </div>
# <ul class="meta-info hidden-md">
# <li>Paperback</li>
# <li>
# <a href="/search/advanced?seriesId=801050">Buster Brain Games</a></li>
# <li>
# <span itemprop="inLanguage" itemtype="http://schema.org/Language">
# <a href="/search/advanced?searchLang=123">English</a></span>
# </li>
# </ul>
# <div class="author-info hidden-md">
#                             By (author)
#
#                                 <span itemprop="author" itemscope="Gareth Moore" itemtype="http://schema.org/Person">
# <a href="/author/Gareth+Moore" itemprop="url">
# <span itemprop="name">
#                                     Gareth Moore</span>
# </a>
# </span>
#                             , Illustrated by
#
#                                 <span itemprop="author" itemscope="Chris Dickason" itemtype="http://schema.org/Person">
# <a href="/author/Chris+Dickason" itemprop="url">
# <span itemprop="name">
#                                     Chris Dickason</span>
# </a>
# </span>
# </div>
# <ul class="social-wrap hidden-xs hidden-sm hidden-md">
# <li class="label">Share</li>
# <li><a href="mailto:?subject=Sharing a book&amp;body=I saw this book at Book Depository and thought you might like it:%0D%0A%0D%0Ahttps://www.bookdepository.com/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491" target="_blank"><i class="icon-em"></i></a></li>
# <li><a href="/share/book?id=27269016&amp;service=facebook&amp;mess=book" target="_blank"><i class="icon-fb"></i></a></li>
# <li><a href="https://twitter.com/intent/tweet?text=I've+discovered+Brain+Games+For+Clever+Kids+(R)&amp;url=https%3a%2f%2fwww.bookdepository.com%2fBrain-Games-For-Clever-Kids-R-Gareth-Moore%2f9781780552491&amp;via=bookdepository" target="_blank"><i class="icon-tw"></i></a></li>
# <li><a href="http://pinterest.com/pin/create/button/?url=https://www.bookdepository.com/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491&amp;media=https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/7805/9781780552491.jpg&amp;description=This-book-is-brimming-with-memory-word-and-number-workouts-codes-battleships-and-mind-bending-spot-the-differences-as-well-as-Japanese-puzzles-including-hanjie-kakuro-futoshiki-sudoku-and-lots-more-Let-the-brain-games-begin" target="_blank"><i class="icon-pi"></i></a></li>
# </ul>
# </div>
# <div class="item-tools">
# <div class="checkout-tools">
# <div class="rating-wrap visible-md">
# <a href="#rating-distribution">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# <span>
#                                         4.26</span>
# <span class="rating-count">
#                                         (163 ratings by Goodreads)
# </span>
# </div>
# <div class="price-info-wrap">
# <div class="item-info-wrap">
# <div class="copy-content visible-md" data-target=".meta-info"></div>
# <div class="copy-content visible-md" data-target=".author-info"></div>
# <div class="hidden-xs hidden-sm">
# <div class="price item-price-wrap" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
# <span class="sale-price">9,14 €</span>
# <meta content="EUR" itemprop="priceCurrency"/>
# <meta content="9.14" itemprop="price"/>
# </div>
# </div>
# <div class="copy-content visible-md visible-xs visible-sm" data-target=".formats-wrap"></div>
# <div class="free-delivery-text">
# <i class="icon-rocket"></i>
# <div>
# <b>Free delivery worldwide</b>
# <span>Expected delivery to Spain in 9-14 business days.</span>
# <br/>
# <br/>
# <a class="edd-help-page-link" href="/help/topic/HelpId/2/When-will-my-order-arrive" target="_blank">
#                                                                         Not ordering to Spain? Click <span class="edd-help-page-link-here">here.<span></span></span></a>
# <br/>
# </div>
# </div>
# <div class="gst-disclaimer" id="brexit_no_fee_message">
# <i class="icon-check"></i>
# <p>Price includes VAT/import taxes for EU delivery</p>
# </div>
# <div class="delivery-santa santa-happy">
# <img alt="Order now for expected delivery to Spain by Christmas" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/gift-expected-icon.svg"/>
# <span>Order now for expected delivery to Spain by Christmas</span>
# </div>
# </div>
# </div>
# <div class="btn-wrap">
# <div class="copy-content visible-xs visible-sm" data-target=".item-price-wrap"></div>
# <a class="btn btn-primary add-to-basket" data-currency="EUR" data-isbn="9781780552491" data-price="9.14" data-show-related="true" href="/basket/addisbn/isbn13/9781780552491">
#                                             Add to basket<input id="isOmnibusApplicable" type="hidden"/>
# </a>
# <a class="btn btn-grey add-to-wishlist" data-isbn="9781780552491" href="/account/wishlistItemUpdate?mainAction=add&amp;isbn13=9781780552491" rel="nofollow">
#                                     Add to wishlist</a>
# <div class="copy-content visible-xs visible-sm" data-target=".social-wrap"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="item-description">
# <h2>Description</h2>
# <div class="item-excerpt trunc" data-height="230" itemprop="description">
#
#                             'A super book for children to enjoy as they puzzle their way through the challenges, which get harder as they progress through the book' - Parents in Touch<br/>
# <br/>
#                             ___________________<br/>
# <br/>
#                             Brain Games for Clever Kids (R) is a fantastic bestselling puzzle book, brimming with memory, word and number workouts for the cleverest of kids!<br/>
# <br/>
#                             Including battleships and mind-bending spot the differences to Japanese puzzles including hanjie, kakuro, futoshiki, sudoku and lots more. <br/>
# <br/>
#                             Let the brain games begin!<br/>
# <br/>
#                             Clever Kids is a trade mark of Michael O'Mara Books Limited.<br/>
# <a class="read-more" tabindex="0">show more</a>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script><div class="biblio-wrap">
# <div class="biblio-info-wrap">
# <h2 class="biblio-title">
#                             Product details</h2>
# <ul class="biblio-info">
# <li>
# <label>For ages</label>
# <span>9-12</span>
# </li>
# <li>
# <label>Format</label>
# <span>
#                                 Paperback
#                                     | <span itemprop="numberOfPages">192 pages
# </span>
# </span>
# </li>
# <li>
# <label>Dimensions</label>
# <span>
#                                 129
#                                     x 198
#                                     x 12mm
#
#                                     | 150g
#                                 </span>
# </li>
# <li>
# <label>Publication date</label>
# <span itemprop="datePublished">01 Oct 2014</span>
# </li>
# <li>
# <label>Publisher</label>
# <span itemprop="publisher" itemscope="Michael O'Mara Books Ltd" itemtype="http://schema.org/Organization">
# <a href="/publishers/Michael-OMara-Books-Ltd" itemprop="url">
# <span itemprop="name">
#                                         Michael O'Mara Books Ltd</span>
# </a>
# </span>
# </li>
# <li>
# <label>Imprint</label>
# <span>Buster Books</span>
# </li>
# <li>
# <label>Publication City/Country</label>
# <span>
#                                 London, United Kingdom</span>
# </li>
# <li>
# <label>Language</label>
# <span>
#                                 English</span>
# </li>
# <li>
# <label>Illustrations note</label>
# <span>illustrations</span>
# </li>
# <li>
# <label>ISBN10</label>
# <span>1780552491</span>
# </li>
# <li>
# <label>ISBN13</label>
# <span itemprop="isbn">9781780552491</span>
# </li>
# <li>
# <label>Bestsellers rank</label>
# <span>
#                                 14</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="detail-page-carousel-wrap">
# <div class="block-wrap series-recommendation-carousel">
# <div class="block-header">
# <h2>Other books in this series</h2>
# </div>
# <div class="block">
# <div class="carousel-wrap carousel-begin">
# <a class="prev-btn">
# <i class="icon-chevron-left"></i>
# </a>
# <div class="tab-wrap module type-book carousel tab-p13">
# <div class="tab">
# <div class="book-item">
# <div class="item-img">
# <a href="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491?ref=bd_ser_1_1">
# <img alt="Brain Games For Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780552491.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491?ref=bd_ser_1_1">
#             Brain Games For Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Brain Games For Clever Kids (R)" href="/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 01 Oct 2014</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">9,14 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780552491" data-price="9.14" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780552491" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Maths-Games-for-Clever-Kids-R-Gareth-Moore/9781780555409?ref=bd_ser_1_1">
# <img alt="Maths Games for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780555409.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Maths-Games-for-Clever-Kids-R-Gareth-Moore/9781780555409?ref=bd_ser_1_1">
#             Maths Games for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Maths Games for Clever Kids (R)" href="/Maths-Games-for-Clever-Kids-R-Gareth-Moore/9781780555409?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 08 Mar 2018</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">9,92 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780555409" data-price="9.92" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780555409" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Wordsearches-for-Clever-Kids-R-Gareth-Moore/9781780553078?ref=bd_ser_1_1">
# <img alt="Wordsearches for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780553078.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Wordsearches-for-Clever-Kids-R-Gareth-Moore/9781780553078?ref=bd_ser_1_1">
#             Wordsearches for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Wordsearches for Clever Kids (R)" href="/Wordsearches-for-Clever-Kids-R-Gareth-Moore/9781780553078?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 12 Feb 2015</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">8,86 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780553078" data-price="8.86" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780553078" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Times-Tables-Games-for-Clever-Kids-R-Gareth-Moore/9781780555621?ref=bd_ser_1_1">
# <img alt="Times Tables Games for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780555621.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Times-Tables-Games-for-Clever-Kids-R-Gareth-Moore/9781780555621?ref=bd_ser_1_1">
#             Times Tables Games for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Times Tables Games for Clever Kids (R)" href="/Times-Tables-Games-for-Clever-Kids-R-Gareth-Moore/9781780555621?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 01 Sep 2020</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">8,62 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780555621" data-price="8.62" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780555621" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Quiz-Book-for-Clever-Kids-R-Lauren-Farnsworth/9781780553146?ref=bd_ser_1_1">
# <img alt="Quiz Book for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780553146.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Quiz-Book-for-Clever-Kids-R-Lauren-Farnsworth/9781780553146?ref=bd_ser_1_1">
#             Quiz Book for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Lauren-Farnsworth">
#                         Lauren Farnsworth</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Quiz Book for Clever Kids (R)" href="/Quiz-Book-for-Clever-Kids-R-Lauren-Farnsworth/9781780553146?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 01 Oct 2015</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">8,86 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780553146" data-price="8.86" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780553146" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Crosswords-for-Clever-Kids-R-Gareth-Moore/9781780553085?ref=bd_ser_1_1">
# <img alt="Crosswords for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780553085.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Crosswords-for-Clever-Kids-R-Gareth-Moore/9781780553085?ref=bd_ser_1_1">
#             Crosswords for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Crosswords for Clever Kids (R)" href="/Crosswords-for-Clever-Kids-R-Gareth-Moore/9781780553085?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 12 Feb 2015</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">8,86 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780553085" data-price="8.86" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780553085" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Brain-Gaming-for-Clever-Kids-R-Gareth-Moore/9781780554723?ref=bd_ser_1_1">
# <img alt="Brain Gaming for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780554723.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Brain-Gaming-for-Clever-Kids-R-Gareth-Moore/9781780554723?ref=bd_ser_1_1">
#             Brain Gaming for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Brain Gaming for Clever Kids (R)" href="/Brain-Gaming-for-Clever-Kids-R-Gareth-Moore/9781780554723?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 08 Mar 2018</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">8,84 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780554723" data-price="8.84" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780554723" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/Word-Games-for-Clever-Kids-R-Gareth-Moore/9781780554730?ref=bd_ser_1_1">
# <img alt="Word Games for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780554730.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/Word-Games-for-Clever-Kids-R-Gareth-Moore/9781780554730?ref=bd_ser_1_1">
#             Word Games for Clever Kids (R)</a>
# </h3>
# <p class="author">
# <a href="/author/Gareth-Moore">
#                         Gareth Moore</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Word Games for Clever Kids (R)" href="/Word-Games-for-Clever-Kids-R-Gareth-Moore/9781780554730?ref=bd_ser_1_1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published">
#                 01 Sep 2020</p>
# <p class="format">
#             Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">8,90 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="" data-isbn="9781780554730" data-price="8.90" data-ref="bd_ser_1_1" data-show-related="false" href="/basket/addisbn/isbn13/9781780554730" rel="nofollow">
#                     Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item">
# <div class="item-img">
# <a href="/10-Minute-Brain-Games-for-Clever-Kids-R-Gareth-Moore/9781780555935?ref=bd_ser_1_1">
# <img alt="10-Minute Brain Games for Clever Kids (R)" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7805/9781780555935.jpg"/>
# </a>
# </div>
# <div class="item-info">
# <h3 class="title">
# <a href="/10-Minute-Brain-Games-for-Clever-Kids-R-Gareth-Moore/9781780555935?ref=bd_ser_1_1">
# ...
# <br/>
#                                     He is also the creator of online brain-training site BrainedUp.com and runs the daily puzzle site PuzzleMix.com.<br/>
# <a class="read-more" tabindex="0">show more</a>
# </div>
# </div>
# </div>
# <div class="rating-distribution-wrap">
# <div class="rating-distribution" id="rating-distribution">
# <h2>Rating details</h2>
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# <span class="rating-count">
#                 163 ratings</span>
# <div itemprop="ratingValue">
#                 4.26 out of 5 stars</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         5</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="55.828220858895705"></span>
# </span>
#
#                     56% (91)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         4</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="22.085889570552148"></span>
# </span>
#
#                     22% (36)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         3</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="17.177914110429448"></span>
# </span>
#
#                     17% (28)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         2</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="2.4539877300613497"></span>
# </span>
#
#                     2% (4)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         1</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="2.4539877300613497"></span>
# </span>
#
#                     2% (4)</div>
# </div>
# </div>
# <div class="ratings-credit-wrap">
# <div class="ratings-credit">
#                             Book ratings by <span id="goodreads-credit"> Goodreads</span></div>
# <div class="goodreads-credit-extended">
# <a class="exit-to-goodreads" href="/external/GR/21470771" target="_blank">Goodreads</a> is the world's largest site for readers with over 50 million reviews. We're featuring millions of their reader ratings on our book pages to help you find your new favourite book.<span class="goodreads-close">
#                         Close</span>
# <span class="goodreads-close-x">
#                          X</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/newsletter/add">
# <div class="form-group">
# <input aria-label="Email address for newsletter subscription" class="form-control" name="newsletterEmailAddress" placeholder="" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                                 Sign up now
#                             </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-social-wrap">
# <h4>
#             Follow us</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Explore</h4>
# <ul>
# <li><a href="/about-us" rel="nofollow">
#                             About us</a></li>
# <li><a href="/sitemap">
#                             Sitemap</a></li>
# <li><a href="/bookmarks">
#                             Bookmarks</a></li>
# <li><a class="footer-sign-in-link" href="/account/login/to/account">
#                                     Sign in/Join</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>How can we help?</h4>
# <ul>
# <li>
# <a href="/help" rel="nofollow">
#                                 Help</a>
# </li>
# <li>
# <a href="/contactus">
#                                 Contact us</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 Where's my stuff?</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 Where do you deliver?</a>
# </li>
# <li>
# <a href="/cancelorder" rel="nofollow">
#                                 Cancel my order</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/30#helpContent" rel="nofollow">
#                                 Return my order</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Join us</h4>
# <ul>
# <li><a href="/affiliate">
#                             Affiliates</a></li>
# <li><a href="/jobs">
#                             Jobs</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Important stuff</h4>
# <ul>
# <li>
# <a href="/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Complaints</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Privacy policy</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Terms &amp; Conditions</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/account/login/to/account" rel="nofollow">
#                                     Sign in/Join</a></li>
# <li><a href="/track">
#                             Order Status</a></li>
# <li><a href="/contactus">
#                             Contact us</a></li>
# <li><a href="/help">
#                             Help</a></li>
# <li><a href="/about-us" rel="nofollow">
#                             About us</a></li>
# <li><a href="/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Terms &amp; Conditions</a></li>
# <li><a href="/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Privacy policy</a></li>
# <li><a href="/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>We accept these payment methods </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-timebased-2022-1', requestTime='0.03 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='91.126.68.164', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Sat Dec 03 12:00:18 UTC 2022, cacheEnabled=true}}">
#                         © 2022
#                         The Book Depository Ltd.UK.<br/>Registered company number: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div class="corner-content hidden" data-ckey-show-from="cornerContent" data-ckey-suppress="cornerContentPosting-Dates-EN" data-show-for="8760">
# <img class="corner-content-img" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.44/img/last-order-icon.svg"/>
# <a class="corner-content-link" href="/Christmas-FAQs">
# <div class="corner-content-text">
# <span class="underline-text">Christmas Posting dates here</span>
# </div>
# </a>
# <a class="close-button" href="#"><i class="icon-close"></i></a>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Shop","bd_js_too_long_for_shipping_label":"Sorry, that's too long for our shipping labels","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Sorry, that's too long","bd_js_could_not_find_address_try_again":"Sorry, we couldn't find the address. Please try again","bd_saving_percent_off":"{0}%&lt;br&gt;off","bd_js_total_basket_count":"{0, plural, one {You have &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;item&lt;/span&gt;&lt;/b&gt; in your basket} other {You have &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;items&lt;/span&gt;&lt;/b&gt; in your basket}}","bd_js_total_cost":"Total cost: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"show less","bd_js_item_added_to_your_basket":"Item added to your basket","bd_rrp":"RRP","bd_link_prefix":"","bd_js_unable_get_address_enter_manually":"Sorry, we are unable to get the address. Please enter manually:","bd_js_keep_typing_to_refine_search_results":"Keep typing to refine the search results","bd_js_top_categories":"Top Categories","bd_price_save":"Save {0}","bd_js_name_only_letters":"Sorry, full name can only contain letters","bd_js_show_more":"show more","bd_js_enter_valid_email_address":"Please enter a valid email address","bd_js_enter_address_manually":"Enter address manually","bd_js_more_categories":"More Categories","bd_30_day_low_price_carousel":"30-day low price","bd_js_continue_shopping":"Continue Shopping","bd_js_account_and_help":"Account &amp; Help","bd_js_basket_checkout":"Basket / Checkout","bd_add_to_basket":"Add to basket","bd_js_enter_first_last_name":"Please enter a first and last name","bd_js_please_enter_your":"Please enter your"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# Obtenemos el titulo del libro

# %%
name = soup_libro.find('h1').text
print(name)
# Out:
# Brain Games For Clever Kids (R)

# %% [markdown]
# El rating

# %%
# soup_libro.find(itemprop="ratingValue").get_text().split(" ")[-1]
# soup_libro.find(itemprop="ratingValue").get_text().replace(" ","").replace("\n","")
rating = soup_libro.find(itemprop="ratingValue").get_text().strip()
rating  = float(rating)
rating
# Out:
# 4.26

# %% [markdown]
# Cantidad de votaciones para el rating

# %%
rating_count = soup_libro.find('span',class_ = 'rating-count').get_text().strip().split(" ")[0].replace("(","")
rating_count = int(rating_count)
print(rating_count)
# Out:
# 163

# %% [markdown]
# Tipo de formato

# %%
soup_libro.find(class_ = 'meta-info hidden-md')
# Out:
# <ul class="meta-info hidden-md">
# <li>Paperback</li>
# <li>
# <a href="/search/advanced?seriesId=801050">Buster Brain Games</a></li>
# <li>
# <span itemprop="inLanguage" itemtype="http://schema.org/Language">
# <a href="/search/advanced?searchLang=123">English</a></span>
# </li>
# </ul>

# %%
formats = soup_libro.find(class_ = 'meta-info hidden-md')('li')[0].text
formats
# Out:
# 'Paperback'

# %% [markdown]
# Autor

# %%
author = soup_libro.find(itemprop= "author").text
author = author.strip()
print(author)
# Out:
# Gareth Moore

# %% [markdown]
# Precio

# %%
price = float(soup_libro.find(class_ = 'sale-price').text.replace("€",'').replace(",",".").strip())
price
# Out:
# 9.14

# %% [markdown]
# Url de la portada

# %%
imagen = soup_libro.find(class_ = 'book-img')['src']
imagen
# Out:
# 'https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/7805/9781780552491.jpg'

# %%
data = []

for url in lista_URLs:
    print(url)
    # Hacemos un nuevo request para el primer libro: 
    r = requests.get(url)

    # Creamos una sopa específica con la info de cada libro
    soup_libro = bs(r.text, "lxml")

    # DATA
    name = soup_libro.find('h1').text
    
    try:
        rating = soup_libro.find(itemprop="ratingValue").get_text().strip()
        rating  = float(rating)

        rating_count = soup_libro.find('span',class_ = 'rating-count').get_text().strip().split(" ")[0].replace("(","").replace(",",'')
        rating_count = int(rating_count)
    except:
        rating = None
        rating_count=None

    formats = soup_libro.find(class_ = 'meta-info hidden-md')('li')[0].text

    author = soup_libro.find(itemprop= "author").text
    author = author.strip()

    price = float(soup_libro.find(class_ = 'sale-price').text.replace("€",'').replace(",",".").strip())

    imagen = soup_libro.find(class_ = 'book-img')['src']

    data_libro = {'nombre':name,
                  'rating':rating,
                  'rating_count':rating_count,
                  'formato':formats,
                  'autor':author,
                  'precio':price,
                  'imagen':imagen,
                  'url':url
    }
    data.append(data_libro)

df = pd.DataFrame(data)
df.head()
# Out:
# https://www.bookdepository.com/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267
# https://www.bookdepository.com/Verity-Colleen-Hoover/9781408726600
# https://www.bookdepository.com/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581
# https://www.bookdepository.com/Atomic-Habits-James-Clear/9781847941831
# https://www.bookdepository.com/Tools-Phil-Stutz/9780812983043
# https://www.bookdepository.com/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697
# https://www.bookdepository.com/Roald-Dahls-Marvellous-Joke-Book-Roald-Dahl/9780141340555
# https://www.bookdepository.com/Letters-from-M-M-Paris-Paul-McNeil/9780500025277
# https://www.bookdepository.com/Midnight-Library-Matt-Haig/9781786892737
# https://www.bookdepository.com/Undaunted-Stalingrad-Trevor-Benjamin/9781472852670
# https://www.bookdepository.com/Where-Crawdads-Sing-Delia-Owens/9781472154668
# https://www.bookdepository.com/Brain-Games-For-Clever-Kids-R-Gareth-Moore/9781780552491
# https://www.bookdepository.com/Secret-History-Donna-Tartt/9780140167771
# https://www.bookdepository.com/Body-Keeps-Score-Bessel-Van-Der-Kolk/9780141978611
# https://www.bookdepository.com/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-5-Special-Edition-Mo-Xiang-Tong-Xiu/9781685798406
# https://www.bookdepository.com/Thursday-Murder-Club-Richard-Osman/9780241988268
# https://www.bookdepository.com/Surrender-Bono/9781529151787
# https://www.bookdepository.com/Grandmaster-Demonic-Cultivation-Mo-Dao-Zu-Shi-Novel-Vol-4-Mo-Xiang-Tong-Xiu/9781638583011
# https://www.bookdepository.com/Im-Glad-My-Mom-Died-Jennette-McCurdy/9781982185824
# https://www.bookdepository.com/Small-Things-Like-These-Claire-Keegan/9780571368709
# https://www.bookdepository.com/Seven-Moons-Maali-Almeida-Shehan-Karunatilaka/9781908745903
# https://www.bookdepository.com/Light-We-Carry-Michelle-Obama/9780241621240
# https://www.bookdepository.com/Taste-Stanley-Tucci/9780241501009
# https://www.bookdepository.com/Good-Girls-Guide-Murder-Holly-Jackson/9781405293181
# https://www.bookdepository.com/World-Simon-Sebag-Montefiore/9780297869672
# https://www.bookdepository.com/Twisted-Love-Ana-Huang/9780349434278
# https://www.bookdepository.com/Diary-Wimpy-Kid-Diper-OEverloede-Book-17-Jeff-Kinney/9780241583081
# https://www.bookdepository.com/Just-One-Thing-Dr-Michael-Mosley/9781780725512
# https://www.bookdepository.com/Ugly-Love-Colleen-Hoover/9781471136726
# https://www.bookdepository.com/They-Know-Not-What-They-Do-Jussi-Valtonen/9781786073532
#                                               nombre  rating  rating_count  \
# 0  It Ends With Us: The most heartbreaking novel ...    4.36     1803902.0
# 1  Verity : The thriller that will capture your h...    4.40     1351569.0
# 2                        Before the Coffee Gets Cold    3.75      158777.0
# 3  Atomic Habits : the life-changing million-copy...    4.38      489376.0
# 4  The Tools : 5 Tools to Help You Find Courage, ...    3.71        3362.0
#
#      formato                autor  precio  \
# 0  Paperback       Colleen Hoover   12.84
# 1  Paperback       Colleen Hoover   11.94
# 2  Paperback  Toshikazu Kawaguchi   14.15
# 3  Paperback          James Clear   20.68
# 4  Paperback           Phil Stutz   20.11
#
#                                               imagen  \
# 0  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 1  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 2  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 3  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 4  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
#
#                                                  url
# 0  https://www.bookdepository.com/It-Ends-With-Us...
# 1  https://www.bookdepository.com/Verity-Colleen-...
# 2  https://www.bookdepository.com/Before-Coffee-G...
# 3  https://www.bookdepository.com/Atomic-Habits-J...
# 4  https://www.bookdepository.com/Tools-Phil-Stut...

# %%
df.shape
# Out:
# (30, 8)

# %% [markdown]
# Ahora lo automatizamos para hacer un web scraping

# %% [markdown]
# ---------------

# %%
df.to_csv('libros.csv',sep="~",header=True,index=False)
